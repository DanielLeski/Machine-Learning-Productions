# %% [markdown]
# By: Daniel Leskewicz, Kenneth Mcdonough

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
import json
import numpy as np
import glob
import csv
from collections import Counter
from imblearn.over_sampling import RandomOverSampler, SMOTE
import matplotlib.pyplot as plt 
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn import preprocessing

# %% [markdown]
# ## Data Extraction

# %%
email_path = '/home/oko/Desktop/ml-production-systems-data/email_json_dataset1'

json_pattern = os.path.join(email_path,'*.json')
file_list = glob.glob(json_pattern)

# %%
data = [] # These are going to be dataframes

# %%
for file in file_list:
    email_data = pd.read_json(file, lines=True) # read data frame from json file
    data.append(email_data) # append the data frame to the list

temp = pd.concat(data, ignore_index=True)
temp = temp.astype(str)

# %%
display(temp)
# Out:
#       label                                         to_address  \
# 0      spam                         manager@flax9.uwaterloo.ca
# 1       ham            Spencer Graves <spencer.graves@pdf.com>
# 2      spam                     <ktwarwic@speedy.uwaterloo.ca>
# 3       ham            "avcavc" <ktwarwic@speedy.uwaterloo.ca>
# 4       ham                     James Peach <jpeach@samba.org>
# ...     ...                                                ...
# 63537  spam                       cruiseca@speedy.uwaterloo.ca
# 63538  spam                      <ktwarwic@flax9.uwaterloo.ca>
# 63539  spam               producttestpanel@speedy.uwaterloo.ca
# 63540   ham                           r-help@stat.math.ethz.ch
# 63541  spam  <the00@plg.uwaterloo.ca>, <adtrevors@plg.uwate...
#
#                                             from_address  \
# 0        "Ramirez, Ismael" <Lay1S@crossstitchcrazy.info>
# 1              Prof Brian Ripley <ripley@stats.ox.ac.uk>
# 2      "Miguel Torres" <radiobarn.com@dpweb.vendaregr...
# 3      "AccuWeather.com Alert" <inbox@messaging.accuw...
# 4            Volker Lendecke <Volker.Lendecke@SerNet.DE>
# ...                                                  ...
# 63537      "Condom Giveaway" <return@anythingrading.com>
# 63538  "Sherman Nichols" <libertineDeimos@secretservi...
# 63539       PremierOffer <PremierOffer@accesssender.com>
# 63540                    Megh Dal <megh700004@yahoo.com>
# 63541                "Dana" <qcevnkbybt@slingshot.co.nz>
#
#                                                  subject  \
# 0      Please respond to your loan application  Sun, ...
# 1                           Re: [R] PCA  for Binary data
# 2                                  Software At Low Pr1ce
# 3           AccuWeather.com Alert(tm) Advisory  (avcavc)
# 4       Re: setgroups problems on FreeBSD - proposed fix
# ...                                                  ...
# 63537  Condom Sampler Pack Giveaway - Its Always Bett...
# 63538                    re:Medications for US residents
# 63539         adf, Join More Than 3 Million Card Holders
# 63540                    [R] Calculating Percentile in R
# 63541                        Re: Loo..king fo.r frien.d?
#
#                                                     body
# 0      \n\nDear Homeowner,\n\nWould you like to reduc...
# 1      On Tue, 12 Jun 2007, Spencer Graves wrote:\n\n...
# 2      \n\nHi\n\n\n\n\n\n\nIn 1963 when he met Jack T...
# 3      \n\nAccuWeather.com Alert[TM]\n\n\n\n\n\n\n\n\...
# 4
# ...                                                  ...
# 63537  \n\n\n\n\n\n\nI Want My \n      Condoms!©2003-...
# 63538  \n\n\n\n\n\n\n\nDear customer.\nUSA Web pharma...
# 63539  \n\n251839499/  Infobox President// name   Glo...
# 63540  Hi all,\n \nI have a problem on how R calculat...
# 63541  Hire,\ni am here sitting in the internet caffe...
#
# [63542 rows x 5 columns]

# %% [markdown]
# Q1: The column names within this panda dataframe are label, to_address, from_address, subject, and body. I have made all of the columns data type into strings.

# %% [markdown]
# ## Extract Features

# %%
vectorizer = CountVectorizer(min_df=10) #creating a instance of CountVectorizer

# %%
bodies = temp['body'].values

# %%
X = vectorizer.fit_transform(bodies)

# %%
print("Vectorizer Vocabulary: ", vectorizer.vocabulary_)
# Out:
# Vectorizer Vocabulary:  {'dear': 9551, 'homeowner': 14925, 'would': 31720, 'you': 31975, 'like': 17679, 'to': 29146, 'reduce': 24029, 'your': 31984, 'mortgage': 19441, 'payment': 21593, 'refinance': 24062, 'with': 31574, 'us': 30278, 'for': 12934, 'better': 5833, 'rate': 23740, 'approval': 4687, 'is': 16290, 'waiting': 31020, 'can': 6874, 'receive': 23906, '244': 2005, '000': 1, '689': 2971, 'per': 21734, 'month': 19381, 'save': 25421, '45': 2570, 'please': 22215, 'respond': 24542, 'now': 20376, 'http': 15095, 'ilook': 15384, 'tw': 29714, 'academy': 3632, 'finance': 12632, 'enjoy': 11497, 'when': 31347, 'and': 4446, 'endure': 11447, 'must': 19661, 'johann': 16566, 'wolfgang': 31625, 'von': 30908, 'on': 20799, 'tue': 29650, '12': 1467, 'jun': 16672, '2007': 1842, 'spencer': 27106, 'graves': 14027, 'wrote': 31768, 'the': 28803, 'problem': 22955, 'applying': 4661, 'prcomp': 22664, 'binary': 5913, 'data': 9434, 'that': 28798, 'it': 16331, 'not': 20320, 'clear': 7692, 'what': 31333, 'are': 4759, 'solving': 26865, 'standard': 27367, 'principal': 22888, 'components': 8183, 'factor': 12262, 'analysis': 4416, 'models': 19261, 'assume': 4967, 'observations': 20599, 'linear': 17716, 'combinations': 7993, 'of': 20678, 'common': 8071, 'factors': 12264, 'shared': 26040, 'variability': 30479, 'normally': 20297, 'distributed': 10441, 'plus': 22270, 'normal': 20291, 'noise': 20247, 'independent': 15634, 'between': 5836, 'variables': 30481, 'those': 28929, 'assumptions': 4972, 'clearly': 7698, 'violated': 30780, 'rsitesearch': 25082, 'pca': 21608, 'produced': 22991, 'references': 24050, 'ade4': 3838, 'have': 14506, 'considered': 8431, 'these': 28861, 'used': 30298, 'them': 28822, 'but': 6690, 'included': 15573, 'functions': 13292, 'multiple': 19606, 'mixed': 19185, 'quantitative': 23495, 'qualitative': 23484, 'afaik': 3983, 'using': 30320, 'in': 15531, 'same': 25313, 'sense': 25834, 'as': 4871, 'factanal': 12259, 'continuous': 8557, 'underlying': 29955, 'manifest': 18373, 'part': 21450, 'latent': 17248, 'variable': 30480, 'package': 21264, 'covers': 8865, 'variety': 30495, 'such': 27901, 'begin': 5656, 'give': 13733, 'advice': 3947, 'we': 31179, 'need': 19927, 'know': 16967, 'scientific': 25551, 'which': 31361, 'chandra': 7274, 'looking': 17970, 'tool': 29221, 'simon': 26365, 'blomberg': 6100, 'mentioned': 18826, 'only': 20831, 'one': 20807, 'several': 25967, 'classes': 7656, 'uses': 30316, 'finds': 12654, 'both': 6281, 'has': 14461, 'maximal': 18593, 'variance': 30482, 'within': 31586, 'least': 17394, 'squares': 27256, 'fitting': 12729, 'hope': 14976, 'this': 28913, 'helps': 14666, 'josh': 16603, 'gilbert': 13703, 'don': 10601, 'understand': 29962, 'wrong': 31764, 'situation': 26443, 'sunday': 27972, '10': 1335, 'june': 16675, '50': 2674, 'pm': 22274, 'hi': 14756, 'was': 31114, 'wondering': 31639, 'whether': 31359, 'there': 28848, 'any': 4572, 'implementing': 15468, 'component': 8182, 'thanks': 28795, 'alternative': 4302, 'html': 15093, 'version': 30622, 'deleted': 9752, '______________________________________________': 3434, 'help': 14655, 'stat': 27407, 'math': 18555, 'ethz': 11819, 'ch': 7239, 'mailing': 18257, 'list': 17765, 'https': 15098, 'mailman': 18263, 'listinfo': 17780, 'do': 10521, 'read': 23819, 'posting': 22555, 'guide': 14214, 'www': 31790, 'project': 23063, 'org': 20985, 'provide': 23201, 'commented': 8044, 'minimal': 19073, 'self': 25784, 'contained': 8508, 'reproducible': 24428, 'code': 7871, 'brian': 6434, 'ripley': 24807, 'stats': 27437, 'ox': 21232, 'ac': 3607, 'uk': 29854, 'professor': 23019, 'applied': 4657, 'statistics': 27432, 'university': 30073, 'oxford': 21234, 'tel': 28613, '44': 2550, '1865': 1677, '272861': 2084, 'south': 26955, 'parks': 21412, 'road': 24870, '272866': 2085, 'pa': 21254, 'ox1': 21233, '3tg': 2411, 'fax': 12407, '272595': 2083, '1963': 1734, 'he': 14545, 'met': 18904, 'jack': 16393, 'twist': 29729, 'they': 28874, 'shook': 26143, 'hands': 14368, 'choky': 7472, 'forest': 12970, 'service': 25916, 'go ...

# %%
print("Feature Matrix: ", X, X.shape)
print("Matrix Nonzero: ", X.count_nonzero())
# Out:
# Feature Matrix:    (0, 9551)	1
#   (0, 14925)	1
#   (0, 31720)	1
#   (0, 31975)	4
#   (0, 17679)	1
#   (0, 29146)	1
#   (0, 24029)	1
#   (0, 31984)	2
#   (0, 19441)	1
#   (0, 21593)	1
#   (0, 24062)	1
#   (0, 31574)	1
#   (0, 30278)	1
#   (0, 12934)	2
#   (0, 5833)	1
#   (0, 23740)	1
#   (0, 4687)	1
#   (0, 16290)	1
#   (0, 31020)	1
#   (0, 6874)	2
#   (0, 23906)	1
#   (0, 2005)	1
#   (0, 1)	1
#   (0, 2971)	1
#   (0, 21734)	1
#   :	:
#   (63541, 19683)	1
#   (63541, 5011)	1
#   (63541, 15321)	1
#   (63541, 1550)	1
#   (63541, 15750)	1
#   (63541, 11279)	3
#   (63541, 16080)	1
#   (63541, 13054)	1
#   (63541, 2024)	1
#   (63541, 13720)	1
#   (63541, 26770)	1
#   (63541, 14693)	2
#   (63541, 18998)	1
#   (63541, 9488)	1
#   (63541, 9608)	2
#   (63541, 24389)	1
#   (63541, 31757)	2
#   (63541, 18730)	1
#   (63541, 21996)	1
#   (63541, 14816)	1
#   (63541, 7132)	1
#   (63541, 26441)	1
#   (63541, 6298)	1
#   (63541, 6791)	1
#   (63541, 22135)	1 (63542, 32144)
# Matrix Nonzero:  6388757

# %% [markdown]
# Q2: The feature matrix has 63542 rows and 32144 columns. The amount of nonzero values are 6388757.

# %% [markdown]
# ## Create and Evaluate a Simple Classifier

# %%
labels = temp['label'] #grabbing our labels

#using label Encoder to encode our data
label_encoder = preprocessing.LabelEncoder()

temp['Encoded_Labels'] = label_encoder.fit_transform(labels)

#use the new encoded labels
encoded_labels = temp['Encoded_Labels'] 
# Spam = 1, Ham = 0

display(temp)
# Out:
#       label                                         to_address  \
# 0      spam                         manager@flax9.uwaterloo.ca
# 1       ham            Spencer Graves <spencer.graves@pdf.com>
# 2      spam                     <ktwarwic@speedy.uwaterloo.ca>
# 3       ham            "avcavc" <ktwarwic@speedy.uwaterloo.ca>
# 4       ham                     James Peach <jpeach@samba.org>
# ...     ...                                                ...
# 63537  spam                       cruiseca@speedy.uwaterloo.ca
# 63538  spam                      <ktwarwic@flax9.uwaterloo.ca>
# 63539  spam               producttestpanel@speedy.uwaterloo.ca
# 63540   ham                           r-help@stat.math.ethz.ch
# 63541  spam  <the00@plg.uwaterloo.ca>, <adtrevors@plg.uwate...
#
#                                             from_address  \
# 0        "Ramirez, Ismael" <Lay1S@crossstitchcrazy.info>
# 1              Prof Brian Ripley <ripley@stats.ox.ac.uk>
# 2      "Miguel Torres" <radiobarn.com@dpweb.vendaregr...
# 3      "AccuWeather.com Alert" <inbox@messaging.accuw...
# 4            Volker Lendecke <Volker.Lendecke@SerNet.DE>
# ...                                                  ...
# 63537      "Condom Giveaway" <return@anythingrading.com>
# 63538  "Sherman Nichols" <libertineDeimos@secretservi...
# 63539       PremierOffer <PremierOffer@accesssender.com>
# 63540                    Megh Dal <megh700004@yahoo.com>
# 63541                "Dana" <qcevnkbybt@slingshot.co.nz>
#
#                                                  subject  \
# 0      Please respond to your loan application  Sun, ...
# 1                           Re: [R] PCA  for Binary data
# 2                                  Software At Low Pr1ce
# 3           AccuWeather.com Alert(tm) Advisory  (avcavc)
# 4       Re: setgroups problems on FreeBSD - proposed fix
# ...                                                  ...
# 63537  Condom Sampler Pack Giveaway - Its Always Bett...
# 63538                    re:Medications for US residents
# 63539         adf, Join More Than 3 Million Card Holders
# 63540                    [R] Calculating Percentile in R
# 63541                        Re: Loo..king fo.r frien.d?
#
#                                                     body  Encoded_Labels
# 0      \n\nDear Homeowner,\n\nWould you like to reduc...               1
# 1      On Tue, 12 Jun 2007, Spencer Graves wrote:\n\n...               0
# 2      \n\nHi\n\n\n\n\n\n\nIn 1963 when he met Jack T...               1
# 3      \n\nAccuWeather.com Alert[TM]\n\n\n\n\n\n\n\n\...               0
# 4                                                                      0
# ...                                                  ...             ...
# 63537  \n\n\n\n\n\n\nI Want My \n      Condoms!©2003-...               1
# 63538  \n\n\n\n\n\n\n\nDear customer.\nUSA Web pharma...               1
# 63539  \n\n251839499/  Infobox President// name   Glo...               1
# 63540  Hi all,\n \nI have a problem on how R calculat...               0
# 63541  Hire,\ni am here sitting in the internet caffe...               1
#
# [63542 rows x 6 columns]

# %%
X_train, x_test, y_train, y_test = train_test_split(X, encoded_labels)

# %%
clf = MLPClassifier() #creating an instance of an MLP classifier

clf.fit(X_train, y_train) #fitting our MLP model
# Out:
# MLPClassifier()

# %%
y_pred = clf.predict(x_test)
y_pred_proba = clf.predict_proba(x_test)

# %%
## Report
print("Accuracy Score: " , accuracy_score(y_true=y_test, y_pred=y_pred))
print("Recall Score: ", recall_score(y_true=y_test, y_pred=y_pred, pos_label=0))
print("Percision Score: ", precision_score(y_true=y_test, y_pred=y_pred, pos_label=0))

fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba[:,1])
plt.plot(fpr,tpr)
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()
# Out:
# Accuracy Score:  0.968840488480423
# Recall Score:  0.923036831132731
# Percision Score:  0.9903075489282386

# %% [markdown]
# ### Exploring Class Imbalance

# %%
#Looking at the class imbalance between ham and spam
print(Counter(labels).keys())
print(Counter(labels).values())

ax = temp.label.value_counts().plot(kind='bar')
_ = ax.set_title('Frequency of Classes, Imbalanced')
# Out:
# dict_keys(['spam', 'ham'])
# dict_values([40450, 23092])

# %% [markdown]
# As we can see with the figure above there is a significant number of spam compared to ham. We can perform techniques such as over sampling or undersampling to fix this issue.

# %% [markdown]
# ### Random Over-Sampling Dataset

# %%
ros = RandomOverSampler(random_state=42)

#creating new training set
X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)

print(sorted(Counter(y_train_ros).items()))
#From this we can see that most classes have 30320 items in them.
# Out:
# [(0, 30320), (1, 30320)]

# %%
# Creating and Training our MLP again
clf_ros = MLPClassifier() #creating an instance of an MLP classifier

clf_ros.fit(X_train_ros, y_train_ros) #fitting our MLP model

y_pred_ros = clf_ros.predict(x_test)
y_pred_proba_ros = clf_ros.predict_proba(x_test)

# %%
## Report
print("Accuracy Score: " , accuracy_score(y_true=y_test, y_pred=y_pred_ros))
print("Recall Score: ", recall_score(y_true=y_test, y_pred=y_pred_ros, pos_label=0))
print("Percision Score: ", precision_score(y_true=y_test, y_pred=y_pred_ros, pos_label=0))

fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba_ros[:,1])
plt.plot(fpr,tpr)
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()
# Out:
# Accuracy Score:  0.9689034369885434
# Recall Score:  0.9223419041000694
# Percision Score:  0.9912247946228528

# %% [markdown]
# ### Random Under-Sampling Dataset

# %%
rus = RandomUnderSampler(random_state=42)

X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

print(sorted(Counter(y_train_rus).items()))
#From this we can see that most classes have 17336 items each of them.
# Out:
# [(0, 17336), (1, 17336)]

# %%
# Creating and Training our MLP again
clf_rus = MLPClassifier() #creating an instance of an MLP classifier

clf_rus.fit(X_train_rus, y_train_rus) #fitting our MLP model

y_pred_rus = clf_rus.predict(x_test)
y_pred_proba_rus = clf_rus.predict_proba(x_test)

# %%
## Report
print("Accuracy Score: " , accuracy_score(y_true=y_test, y_pred=y_pred_rus))
print("Recall Score: ", recall_score(y_true=y_test, y_pred=y_pred_rus, pos_label=0))
print("Percision Score: ", precision_score(y_true=y_test, y_pred=y_pred_rus, pos_label=0))

fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba_rus[:,1])
plt.plot(fpr,tpr)
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()
# Out:
# Accuracy Score:  0.9663225481556087
# Recall Score:  0.9265114662960389
# Percision Score:  0.9794306703397613
